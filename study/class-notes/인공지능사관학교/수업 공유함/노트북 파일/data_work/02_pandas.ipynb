# %%
import pandas as pd

# %%
exam=pd.read_csv('./exam.csv')
exam
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
#데이터 파악하기
exam.info()
exam.shape
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       20 non-null     int64
#  1   nclass   20 non-null     int64
#  2   math     20 non-null     int64
#  3   english  20 non-null     int64
#  4   science  20 non-null     int64
# dtypes: int64(5)
# memory usage: 932.0 bytes
# (20, 5)

# %%
# 이런게 다잇네!?!?!?!?!?!?!?
exam.describe()
exam
# Out:
#     id  nclass  math  english  science
# 0    1       1    50       98       50
# 1    2       1    60       97       60
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 5    6       2    50       89       98
# 6    7       2    80       90       45
# 7    8       2    90       78       25
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32
# 12  13       4    46       98       65
# 13  14       4    48       87       12
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 16  17       5    65       68       98
# 17  18       5    80       78       90
# 18  19       5    89       68       87
# 19  20       5    78       83       58

# %%
# nclass 가 1 인 경우에만 추출을 해줘보자
# exam1 = exam[exam['nclass']==1,['maths']]
# 훨씬더 간편한 방법
exam.query('nclass == 1')
# Out:
#    id  nclass  math  english  science
# 0   1       1    50       98       50
# 1   2       1    60       97       60
# 2   3       1    45       86       78
# 3   4       1    30       98       58

# %%
# 1,3,5 반 학생들 출력
exam.query('nclass in [1,3,5]')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Workspace\data_work\vdata\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:174, in pandas._libs.index.IndexEngine.get_loc()
# --> 174 'Could not get source, probably due dynamically evaluated source code.'
#
# TypeError: '(0      True
# 1      True
# 2      True
# 3      True
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# ...

# %%
# 1반 학생들의 수학평균
exam1 = exam.query('nclass == 1')
print(exam1['math'].mean())
# Out:
# 46.25

# %%
var = 3
exam.query('nclass == @var')
# Out:
#     id  nclass  math  english  science
# 8    9       3    20       98       15
# 9   10       3    50       98       45
# 10  11       3    65       65       65
# 11  12       3    45       85       32

# %%
# math가 50 이상인 행만 추출한 다음 id,math 추출
exam.query('math >= 50')[['id','math']]
# Out:
#     id  math
# 0    1    50
# 1    2    60
# 5    6    50
# 6    7    80
# 7    8    90
# 9   10    50
# 10  11    65
# 14  15    75
# 15  16    58
# 16  17    65
# 17  18    80
# 18  19    89
# 19  20    78

# %%
# 정렬 하는 내용 order by
# 디폴트 오름차순
exam.sort_values('math', ascending=False)
# Out:
#     id  nclass  math  english  science
# 7    8       2    90       78       25
# 18  19       5    89       68       87
# 6    7       2    80       90       45
# 17  18       5    80       78       90
# 19  20       5    78       83       58
# 14  15       4    75       56       78
# 10  11       3    65       65       65
# 16  17       5    65       68       98
# 1    2       1    60       97       60
# 15  16       4    58       98       65
# 0    1       1    50       98       50
# 5    6       2    50       89       98
# 9   10       3    50       98       45
# 13  14       4    48       87       12
# 12  13       4    46       98       65
# 2    3       1    45       86       78
# 11  12       3    45       85       32
# 3    4       1    30       98       58
# 4    5       2    25       80       65
# 8    9       3    20       98       15

# %%
exam.sort_values(['nclass','math'], ascending = [True,False])
# Out:
#     id  nclass  math  english  science
# 1    2       1    60       97       60
# 0    1       1    50       98       50
# 2    3       1    45       86       78
# 3    4       1    30       98       58
# 7    8       2    90       78       25
# 6    7       2    80       90       45
# 5    6       2    50       89       98
# 4    5       2    25       80       65
# 10  11       3    65       65       65
# 9   10       3    50       98       45
# 11  12       3    45       85       32
# 8    9       3    20       98       15
# 14  15       4    75       56       78
# 15  16       4    58       98       65
# 13  14       4    48       87       12
# 12  13       4    46       98       65
# 18  19       5    89       68       87
# 17  18       5    80       78       90
# 19  20       5    78       83       58
# 16  17       5    65       68       98

# %%
# 파생 컬럼 필요에 따라서 5개에서 6,7개 만들기 
exam.assign(total = exam['math'] + exam['english'] + exam['science'])
# Out:
#     id  nclass  math  english  science  total
# 0    1       1    50       98       50    198
# 1    2       1    60       97       60    217
# 2    3       1    45       86       78    209
# 3    4       1    30       98       58    186
# 4    5       2    25       80       65    170
# 5    6       2    50       89       98    237
# 6    7       2    80       90       45    215
# 7    8       2    90       78       25    193
# 8    9       3    20       98       15    133
# 9   10       3    50       98       45    193
# 10  11       3    65       65       65    195
# 11  12       3    45       85       32    162
# 12  13       4    46       98       65    209
# 13  14       4    48       87       12    147
# 14  15       4    75       56       78    209
# 15  16       4    58       98       65    221
# 16  17       5    65       68       98    231
# 17  18       5    80       78       90    248
# 18  19       5    89       68       87    244
# ...

# %%
import numpy as np # <<< 기습 입갤 뭐야 얘?!?!!??!!??!!?
#np.where(조건,'조건 만족','조건 만족 X')
exam.assign(test = np.where((exam['math']>=60) | (exam['english'] >=90) , 'pass', 'fail'))
# Out:
#     id  nclass  math  english  science  test
# 0    1       1    50       98       50  pass
# 1    2       1    60       97       60  pass
# 2    3       1    45       86       78  fail
# 3    4       1    30       98       58  pass
# 4    5       2    25       80       65  fail
# 5    6       2    50       89       98  fail
# 6    7       2    80       90       45  pass
# 7    8       2    90       78       25  pass
# 8    9       3    20       98       15  pass
# 9   10       3    50       98       45  pass
# 10  11       3    65       65       65  pass
# 11  12       3    45       85       32  fail
# 12  13       4    46       98       65  pass
# 13  14       4    48       87       12  fail
# 14  15       4    75       56       78  pass
# 15  16       4    58       98       65  pass
# 16  17       5    65       68       98  pass
# 17  18       5    80       78       90  pass
# 18  19       5    89       68       87  pass
# 19  20       5    78       83       58  pass

# %%
netflix = pd.read_csv('./netflix_cleaned.csv')
netflix
# Out:
#    show_id     type                                      title  \
# 0        1  TV Show                                 Squid Game
# 1        2  TV Show                            Stranger Things
# 2        3    Movie                            Sherlock Holmes
# 3        4    Movie  Iron Man & Captain America: Heroes United
# 4        5    Movie                                   Bird Box
# 5        6  TV Show                             Anne with an E
# 6        7    Movie                                 About Time
# 7        8    Movie                                  Inception
#
#             director               cast                 country  release_year  \
# 0            No Data       Lee Jung-jae                 No Data          2021
# 1            No Data       Winona Ryder           United States          2019
# 2        Guy Ritchie   Robert Downey Jr  United States, Germany          2009
# 3          Leo Riley      Adrian Pasdar           United States          2014
# ...
